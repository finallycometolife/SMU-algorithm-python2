# %%
def lcs_dc(X, Y, m, n):
  if m == 0 or n == 0: # base case
    return 0
  elif X[m-1] == Y[n-1]:
    return 1 + lcs_dc(X, Y, m-1, n-1)
  else:
    return max(lcs_dc(X, Y, m, n-1), lcs_dc(X, Y, m-1, n))

def lcs_dp(X, Y):
  m = len(X)
  n = len(Y)
  L = [[None]*(n+1) for _ in range(m+1)] # table 

  for i in range(m+1):
    for j in range(n+1):
      if i == 0 or j == 0: # base case 하나의 길이라도 0이면
        L[i][j] = 0 # lcs --> 0
      elif X[i-1] == Y[j-1]: # 마지막 글자가 같으면
        L[i][j] = L[i-1][j-1]+1
      else: # 마지막 글자가 다르면
        L[i][j] = max(L[i-1][j], L[i][j-1])

  for i in range(m+1):
    print(L[i])

  print("LCS = ", lcs_dp_traceback(X, Y, L))

  return L[m][n]

def lcs_dp_traceback(X, Y, L):
  lcs = ""
  i = len(X)
  j = len(Y)
  while i > 0  and j > 0:
    v = L[i][j]
    if  v > L[i][j-1] and v < L[i-1][j] and v > L[i-1][j-1]:
      i -= 1
      j -= 1
      lcs = X[i] + lcs

    elif v == L[i][j-1] and v > L[i-1][j]: j -= 1
    else : i -= 1
  return lcs

X = "game over"
Y = "hello world"
print("X = ", X)
print("Y = ", Y)
print("LCS(분할 정복)", lcs_dc(X, Y, len(X), len(Y)))
print("LCS(동적 계획)", lcs_dp(X, Y))

# %%
def edit_distance_dp(S, T, m, n):
  E = [[0*(n+1)] for _ in range(m+1)]
  for i in range(m+1):
    E[i][0] = i
  for j in range(n+1):
    E[0][j] = j

  for i in range(1, m+1):
    for j in range(1, n+1):
      if S[i] == T[j-1]: a = 0
      else: a = 1
      E[i][j] = min(E[i-1][j] + 1, E[i][j-1] + 1, E[I-1][j-1]+a)

  return E[m][n]

S = "tuesday"
T = "thursday"
m = len(S)
n = len(T)
print("문자열: ", S, T)
print("dynamic table = ", edit_distance_dp(S, T, m, n))
# Out:
# 문자열:  tuesday thursday
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-95d67240a99f> in <module>()
#      19 n = len(T)
#      20 print("문자열: ", S, T)
# ---> 21 print("dynamic table = ", edit_distance_dp(S, T, m, n))
#
# <ipython-input-35-95d67240a99f> in edit_distance_dp(S, T, m, n)
#       4     E[i][0] = i
#       5   for j in range(n+1):
# ----> 6     E[0][j] = j
#       7
#       8   for i in range(1, m+1):
#
# IndexError: list assignment index out of range
